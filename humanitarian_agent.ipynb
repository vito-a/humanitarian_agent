# %%
from src.db import init_db
from src.ingest.rss_loader import load_country
from src.report.compose import build_country_report
from src.utils.branding import format_us_date
from src.validate.validators import validate_report
from src.report.docx_pdf import generate_docx_structured, generate_pdf_structured

init_db()

#for c in ["ukraine", "syria", "yemen"]:
for c in ["ukraine"]:
    load_country(c, max_items=70)
    report = build_country_report(c)
#    errors = validate_report(report)
#    print("Validation:", "PASS" if not errors else errors)
#    Optional: build an executive summary (or leave as empty string)
#    If you have llm_overview_plain already, plug it in; otherwise just pass "".
#    exec_overview = ""  # or llm_overview_plain(report.get("overview_texts", []))
    sections, refs, as_of = report["sections"], report["references_by_num"], report["as_of"]
#    If valid (or accept minor non-critical issues), render
    base = f"humanitarian_digest_{c}_{as_of}"
    title = f"Humanitarian Situation Digest: {c.title()} — {format_us_date()}",
    generate_docx_structured(sections, refs, "", f"data/reports/{base}.docx", country=c, report_title=title, section_order=report.get("section_order"))
    generate_pdf_structured(sections, refs, "", f"data/reports/{base}.pdf", country=c, report_title=title, section_order=report.get("section_order"))
# Out:
# /home/jovyan/work/humanitarian_agent/data/rss.sqlite3
#
# 🌍 Loading articles for: Ukraine (target accepts=70, max attempts=420)
#   🔗 Fetching feed: https://news.un.org/feed/subscribe/en/news/region/europe/feed/rss.xml
#   💾 Feed cache hit (fresh): news.un.org/023d4a80ab_2025-09-16.xml
#       ⚠️ Got 30 from feed: https://news.un.org/feed/subscribe/en/news/region/europe/feed/rss.xml
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165838
#
#       🆕 Fetched & cached: news.un.org/2d0f48b28a_2025-09-18.html
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-71, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 2, 'human_harm': 1, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 5, 'neg_exclude': 0, 'neg_frontline': 1}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': -15}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': -15, 'allow_bonus': 1}, 'boosted_score': -71, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165834
#
#       🆕 Fetched & cached: news.un.org/579c1ccad9_2025-09-18.html
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-26, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 2, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 6, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -120, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -120, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -26, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165820
#
#       🆕 Fetched & cached: news.un.org/1504e45583_2025-09-18.html
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-6, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 1, 'human_harm': 3, 'health': 0, 'energy': 1, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 5, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 60, 'health': 0, 'energy': 6, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 60, 'health': 0, 'energy': 6, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -6, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165803
#
#       🆕 Fetched & cached: news.un.org/b019fe2a68_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=119, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 1, 'actors': 0, 'military': 2, 'human_harm': 3, 'health': 7, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 70, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 70, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 119, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine: Russian strike on village kills over 20, mostly pensioners, reason : crisis_hits=43 score=119
#
#   3. ✅ Light LLM main gate pass: Ukraine: Russian strike on village kills over 20, mostly pensioners, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 100, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on a specific Russian airstrike in Ukraine resulting in civilian casualties, directly impacting Ukrainian civilians and their daily lives. It aligns with the Security & Civilian Impact section by detailing harm done to civilians in Ukraine.'}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine: Russian strike on village kills over 20, mostly pensioners (keep=True, keep_by_summary=False, llm_pass=True)
# simple=119; summary_raw=239; norm=239.00;z_ref=(220.64,184.99); p70=253.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article details a Russian airstrike on a Ukrainian village resulting in civilian casualties, including pensioners, directly relating to security and civilian impact. It also touches upon the health impact due to injuries.'}
#   5. ✅ Heavy LLM final gate pass: Ukraine: Russian strike on village kills over 20, mostly pensioners (keep=True, keep_by_summary=False, llm_pass=True)
# simple=119; summary_raw=239; norm=239.00;z_ref=(220.64,184.99); p70=253.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article details a Russian airstrike on a Ukrainian village resulting in civilian casualties, including pensioners, directly relating to security and civilian impact. It also touches upon the health impact due to injuries.'}
#     ✅ Cached: Ukraine: Russian strike on village kills over 20, mostly pensioners | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165793
#
#       🆕 Fetched & cached: news.un.org/5bc3eb8094_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=61, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 61, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : UN provides urgent support after ‘massive’ Russian attack across Ukraine, reason : crisis_hits=31 score=61
#
#   3. ✅ Light LLM main gate pass: UN provides urgent support after ‘massive’ Russian attack across Ukraine, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the impact of Russian attacks on Ukrainian civilians, infrastructure, and health services. It mentions a baby killed in an attack, damage to civilian infrastructure, and the protection of civilians under international law. This aligns directly with the Security & Civilian Impact section.'}
#
#   4. ✅ Heavy LLM outer gate pass: UN provides urgent support after ‘massive’ Russian attack across Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=61; summary_raw=181; norm=181.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article details civilian casualties and damage to civilian infrastructure resulting from a Russian attack on Ukraine, aligning with the allowed sections of Security & Civilian Impact and Health & Medical Services.'}
#   5. ✅ Heavy LLM final gate pass: UN provides urgent support after ‘massive’ Russian attack across Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=61; summary_raw=181; norm=181.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article details civilian casualties and damage to civilian infrastructure resulting from a Russian attack on Ukraine, aligning with the allowed sections of Security & Civilian Impact and Health & Medical Services.'}
#     ✅ Cached: UN provides urgent support after ‘massive’ Russian attack across Ukraine | UN Ne... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165773
#
#       🆕 Fetched & cached: news.un.org/de1511ef60_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=81, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 2, 'health': 3, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 81, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Finding strength amid sleepless nights: Ukraine’s hidden mental health toll, reason : crisis_hits=14 score=81
#
#   3. ❌ Light LLM main gate rejected: Finding strength amid sleepless nights: Ukraine’s hidden mental health toll, liquid/lfm2-1.2b rejects that, reason : {'pass': False, 'confidence': 65, 'sections': ['Security & Civilian Impact'], 'reason': "While the article touches on the impact of the invasion on civilians, its primary focus is not on Ukraine's security situation or counterattacks but rather on the mental health toll, specifically the hidden impact on civilians' well-being. The mention of shelling and air raids indicates civilian suffering, but the article does not delve deeply into security measures or counterattacks by Ukraine."}
#
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165750
#
#       🆕 Fetched & cached: news.un.org/84071901cf_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=35, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 1, 'human_harm': 2, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 40, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 40, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 35, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes, reason : crisis_hits=18 score=35
#
#   3. ✅ Light LLM main gate pass: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the impact of Russian attacks on civilians in Ukraine, specifically mentioning casualties and destruction in Kyiv. This directly aligns with the 'Security & Civilian Impact' section, detailing harm done to civilians and the broader impact on Ukraine's population and infrastructure."}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes (keep=True, keep_by_summary=False, llm_pass=True)
# simple=35; summary_raw=115; norm=115.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on Russian strikes against civilians in Ukraine, causing casualties and damage, directly relating to the 'Security & Civilian Impact' section."}
#   5. ✅ Heavy LLM final gate pass: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes (keep=True, keep_by_summary=False, llm_pass=True)
# simple=35; summary_raw=115; norm=115.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on Russian strikes against civilians in Ukraine, causing casualties and damage, directly relating to the 'Security & Civilian Impact' section."}
#     ✅ Cached: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes | UN New... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165733
#
#       🆕 Fetched & cached: news.un.org/b8abf8f3ed_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=165, reason={'host': 'un.org', 'counts': {'core': 4, 'cities': 2, 'actors': 0, 'military': 0, 'human_harm': 5, 'health': 2, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 2, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 60, 'cities': 20, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 24, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 60, 'cities': 20, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 24, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 165, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv, reason : crisis_hits=24 score=165
#
#   3. ✅ Light LLM main gate pass: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the civilian casualties and impact of Russian attacks on Ukrainian cities, specifically mentioning a toddler killed in Ukraine. This directly aligns with the 'Security & Civilian Impact' section, detailing harm done to civilians and infrastructure."}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv (keep=True, keep_by_summary=True, llm_pass=True)
# simple=165; summary_raw=405; norm=405.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly addresses civilian casualties and the impact of attacks on Kyiv, Ukraine, falling under 'Security & Civilian Impact' and 'Health & Medical Services' due to injuries."}
#   5. ✅ Heavy LLM final gate pass: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv (keep=True, keep_by_summary=True, llm_pass=True)
# simple=165; summary_raw=405; norm=405.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly addresses civilian casualties and the impact of attacks on Kyiv, Ukraine, falling under 'Security & Civilian Impact' and 'Health & Medical Services' due to injuries."}
#     ✅ Cached: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv | UN New... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165685
#
#       🆕 Fetched & cached: news.un.org/7a5b327794_2025-09-18.html
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-9, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -9, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165671
#
#       🆕 Fetched & cached: news.un.org/0a4e981507_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=111, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 1, 'actors': 0, 'military': 0, 'human_harm': 4, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 111, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope, reason : crisis_hits=16 score=111
#
#   3. ✅ Light LLM main gate pass: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the humanitarian impact of the conflict in Ukraine, specifically on civilians displaced by the invasion. It highlights the work of a Ukrainian aid worker, Viktoriia Tiutiunnyk, who is directly involved in supporting displaced people, which aligns with the 'Security & Civilian Impact' section."}
#
#   4. ✅ Heavy LLM outer gate pass: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope (keep=True, keep_by_summary=True, llm_pass=True)
# simple=111; summary_raw=271; norm=271.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Aid'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Aid'], 'reason': 'The article focuses on humanitarian aid efforts within Ukraine, specifically detailing the experiences of a UN aid worker operating in the country amidst the conflict. It highlights displacement and trauma, directly relating to civilian impact.'}
#   5. ✅ Heavy LLM final gate pass: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope (keep=True, keep_by_summary=True, llm_pass=True)
# simple=111; summary_raw=271; norm=271.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Aid'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Aid'], 'reason': 'The article focuses on humanitarian aid efforts within Ukraine, specifically detailing the experiences of a UN aid worker operating in the country amidst the conflict. It highlights displacement and trauma, directly relating to civilian impact.'}
#     ✅ Cached: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope | UN... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165668
#
#       🆕 Fetched & cached: news.un.org/417bbbc0f5_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=117, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 2, 'actors': 0, 'military': 2, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 20, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 20, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 117, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’, reason : crisis_hits=13 score=117
#
#   3. ✅ Light LLM main gate pass: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': ''}
#
#   4. ✅ Heavy LLM outer gate pass: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’ (keep=True, keep_by_summary=True, llm_pass=True)
# simple=117; summary_raw=257; norm=257.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article directly discusses civilian casualties from Russian drone strikes in Ukraine, indicating a focus on the security and civilian impact of the conflict. It also mentions the impact on health, as people were killed.'}
#   5. ✅ Heavy LLM final gate pass: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’ (keep=True, keep_by_summary=True, llm_pass=True)
# simple=117; summary_raw=257; norm=257.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article directly discusses civilian casualties from Russian drone strikes in Ukraine, indicating a focus on the security and civilian impact of the conflict. It also mentions the impact on health, as people were killed.'}
#     ✅ Cached: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehe... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165660
#
#       🆕 Fetched & cached: news.un.org/c0fc9291ec_2025-09-18.html
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-9, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -9, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165558
#
#       🆕 Fetched & cached: news.un.org/214fb08c36_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=177, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 6, 'health': 3, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 16, 'human_harm': 120, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 16, 'human_harm': 120, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 177, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : UN official decries deadly Ukraine strikes, urges return to diplomacy, reason : crisis_hits=26 score=177
#
#   3. ✅ Light LLM main gate pass: UN official decries deadly Ukraine strikes, urges return to diplomacy, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the humanitarian impact of Russian strikes on Ukraine, specifically mentioning civilian casualties and worsening conditions. It directly addresses the suffering of Ukrainian civilians and calls for diplomacy, aligning with the Security & Civilian Impact section.'}
#
#   4. ✅ Heavy LLM outer gate pass: UN official decries deadly Ukraine strikes, urges return to diplomacy (keep=True, keep_by_summary=True, llm_pass=True)
# simple=177; summary_raw=417; norm=417.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Crisis'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Crisis'], 'reason': "The article directly addresses civilian casualties and humanitarian conditions in Ukraine due to Russian strikes, aligning with the allowed sections 'Security & Civilian Impact' and 'Humanitarian Crisis'."}
#   5. ✅ Heavy LLM final gate pass: UN official decries deadly Ukraine strikes, urges return to diplomacy (keep=True, keep_by_summary=True, llm_pass=True)
# simple=177; summary_raw=417; norm=417.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Crisis'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Crisis'], 'reason': "The article directly addresses civilian casualties and humanitarian conditions in Ukraine due to Russian strikes, aligning with the allowed sections 'Security & Civilian Impact' and 'Humanitarian Crisis'."}
#     ✅ Cached: UN official decries deadly Ukraine strikes, urges return to diplomacy | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165555
#
#       🆕 Fetched & cached: news.un.org/cf6275d7e5_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=81, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 81, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : LIVE: UN Security Council meets on crisis in Ukraine, reason : crisis_hits=8 score=81
#
#   3. ✅ Light LLM main gate pass: LIVE: UN Security Council meets on crisis in Ukraine, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the UN Security Council meeting regarding the crisis in Ukraine, detailing the situation and expected briefing. It directly addresses harm to civilians, health impacts, and economic consequences, aligning with the allowed sections.'}
#
#   4. ✅ Heavy LLM outer gate pass: LIVE: UN Security Council meets on crisis in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=81; summary_raw=221; norm=221.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article explicitly discusses a crisis in Ukraine and the resulting casualties, falling under 'Security & Civilian Impact'."}
#   5. ✅ Heavy LLM final gate pass: LIVE: UN Security Council meets on crisis in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=81; summary_raw=221; norm=221.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article explicitly discusses a crisis in Ukraine and the resulting casualties, falling under 'Security & Civilian Impact'."}
#     ✅ Cached: LIVE: UN Security Council meets on crisis in Ukraine | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165540
#
#       🆕 Fetched & cached: news.un.org/eb17c15465_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=122, reason={'host': 'un.org', 'counts': {'core': 3, 'cities': 1, 'actors': 0, 'military': 1, 'human_harm': 4, 'health': 3, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 1, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 4, 'human_harm': 80, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 4, 'human_harm': 80, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 122, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Russian attack on Ukrainian capital kills at least 11 civilians, reason : crisis_hits=31 score=122
#
#   3. ✅ Light LLM main gate pass: Russian attack on Ukrainian capital kills at least 11 civilians, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on a Russian attack resulting in civilian casualties and damage in Ukraine's capital Kyiv, directly addressing the harm done to civilians and impacting the country's security and civilian well-being."}
#
#   4. ✅ Heavy LLM outer gate pass: Russian attack on Ukrainian capital kills at least 11 civilians (keep=True, keep_by_summary=True, llm_pass=True)
# simple=122; summary_raw=342; norm=342.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly reports on civilian casualties and injuries resulting from a Russian attack on the capital of Ukraine, clearly falling under 'Security & Civilian Impact' and 'Health & Medical Services'."}
#   5. ✅ Heavy LLM final gate pass: Russian attack on Ukrainian capital kills at least 11 civilians (keep=True, keep_by_summary=True, llm_pass=True)
# simple=122; summary_raw=342; norm=342.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly reports on civilian casualties and injuries resulting from a Russian attack on the capital of Ukraine, clearly falling under 'Security & Civilian Impact' and 'Health & Medical Services'."}
#     ✅ Cached: Russian attack on Ukrainian capital kills at least 11 civilians | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165539
#
#       🆕 Fetched & cached: news.un.org/5b0e1b3d4c_2025-09-18.html
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-71, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 4, 'neg_exclude': 1, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -80, 'neg_exclude': -30, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -80, 'neg_exclude': -30, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -71, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165520
#
#       🆕 Fetched & cached: news.un.org/6f9b8b0358_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=156, reason={'host': 'un.org', 'counts': {'core': 3, 'cities': 1, 'actors': 0, 'military': 0, 'human_harm': 5, 'health': 2, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 156, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Russian attack on Ukrainian prison kills 16: UN rights monitors, reason : crisis_hits=30 score=156
#
#   3. ✅ Light LLM main gate pass: Russian attack on Ukrainian prison kills 16: UN rights monitors, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on a Russian attack on a Ukrainian prison, resulting in civilian casualties and raising concerns about violations of international law. This directly aligns with the 'Security & Civilian Impact' section, detailing harm to civilians and potential breaches of international humanitarian law."}
#
#   4. ✅ Heavy LLM outer gate pass: Russian attack on Ukrainian prison kills 16: UN rights monitors (keep=True, keep_by_summary=True, llm_pass=True)
# simple=156; summary_raw=356; norm=356.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article directly reports on a violent attack on a prison in Ukraine, resulting in civilian casualties and a violation of international law. This clearly falls under 'Security & Civilian Impact'."}
#   5. ✅ Heavy LLM final gate pass: Russian attack on Ukrainian prison kills 16: UN rights monitors (keep=True, keep_by_summary=True, llm_pass=True)
# simple=156; summary_raw=356; norm=356.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article directly reports on a violent attack on a prison in Ukraine, resulting in civilian casualties and a violation of international law. This clearly falls under 'Security & Civilian Impact'."}
#     ✅ Cached: Russian attack on Ukrainian prison kills 16: UN rights monitors | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165499
#
#       🆕 Fetched & cached: news.un.org/8d53bc63d6_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=91, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 4, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 91, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall, reason : crisis_hits=21 score=91
#
#   3. ✅ Light LLM main gate pass: UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the escalating human toll and humanitarian needs in Ukraine due to Russian aerial attacks, directly addressing civilian impact and health/economy concerns as per the allowed sections.'}
#
#   4. ✅ Heavy LLM outer gate pass: UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall (keep=True, keep_by_summary=True, llm_pass=True)
# simple=91; summary_raw=251; norm=251.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Needs'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Needs'], 'reason': 'The article focuses on the escalating human toll and damage to infrastructure in Ukraine due to Russian aerial attacks, directly addressing civilian casualties and humanitarian needs. It meets all criteria for being about Ukraine and relating to allowed sections.'}
#   5. ✅ Heavy LLM final gate pass: UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall (keep=True, keep_by_summary=True, llm_pass=True)
# simple=91; summary_raw=251; norm=251.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Needs'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Needs'], 'reason': 'The article focuses on the escalating human toll and damage to infrastructure in Ukraine due to Russian aerial attacks, directly addressing civilian casualties and humanitarian needs. It meets all criteria for being about Ukraine and relating to allowed sections.'}
#     ✅ Cached: UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mou... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165493
#
#       🆕 Fetched & cached: news.un.org/5c45bdd882_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=51, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 2, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 51, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : SECURITY COUNCIL LIVE: Situation in Ukraine, reason : crisis_hits=6 score=51
#
#   3. ✅ Light LLM main gate pass: SECURITY COUNCIL LIVE: Situation in Ukraine, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 90, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the UN Security Council meeting regarding the situation in Ukraine, directly addressing the impact on civilians and security. It does not mention Ukraine as a country other than in the context of the Security Council meeting.'}
#
#   4. ✅ Heavy LLM outer gate pass: SECURITY COUNCIL LIVE: Situation in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=51; summary_raw=131; norm=131.00;z_ref=(219.44,184.42); p70=251.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article explicitly discusses the situation in Ukraine and the intensifying hostilities, directly relating to security and civilian impact.'}
#   5. ✅ Heavy LLM final gate pass: SECURITY COUNCIL LIVE: Situation in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# ...
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165852
#
#       🆕 Fetched & cached: news.un.org/bfb789ac40_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=52, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 1, 'health': 0, 'energy': 0, 'water': 0, 'food': 2, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 16, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 16, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 52, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : World News in Brief: Pandemic treaty update, DR Congo Ebola response, more casualties in Ukraine, reason : crisis_hits=23 score=52
#
#   3. ✅ Light LLM main gate pass: World News in Brief: Pandemic treaty update, DR Congo Ebola response, more casualties in Ukraine, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on ongoing hostilities and casualties in Ukraine, directly impacting civilians and infrastructure, aligning with the Security & Civilian Impact section.'}
#
#   4. ✅ Heavy LLM outer gate pass: World News in Brief: Pandemic treaty update, DR Congo Ebola response, more casualties in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=52; summary_raw=92; norm=92.00;z_ref=(221.49,185.86); p70=253.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article explicitly discusses casualties, damage to civilian infrastructure (homes, hospital, pharmacy), and displacement of people within Ukraine due to hostilities. This clearly falls under 'Security & Civilian Impact' and 'Health & Medical Services'."}
#   5. ✅ Heavy LLM final gate pass: World News in Brief: Pandemic treaty update, DR Congo Ebola response, more casualties in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=52; summary_raw=92; norm=92.00;z_ref=(221.49,185.86); p70=253.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article explicitly discusses casualties, damage to civilian infrastructure (homes, hospital, pharmacy), and displacement of people within Ukraine due to hostilities. This clearly falls under 'Security & Civilian Impact' and 'Health & Medical Services'."}
#     ✅ Cached: World News in Brief: Pandemic treaty update, DR Congo Ebola response, more casua... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165849
#
#       🆕 Fetched & cached: news.un.org/5f1b18962b_2025-09-18.html
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165847
#
#       🆕 Fetched & cached: news.un.org/0843f419fc_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=39, reason={'host': 'un.org', 'counts': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 2, 'energy': 3, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 20, 'energy': 18, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 20, 'energy': 18, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 39, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : IAEA chief urges countries to recommit to nuclear non-proliferation, reason : crisis_hits=21 score=39
#
#   3. ✅ Light LLM main gate pass: IAEA chief urges countries to recommit to nuclear non-proliferation, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': ''}
#
#   4. ❌ Heavy LLM outer gate rejected: IAEA chief urges countries to recommit to nuclear non-proliferation (keep=True, keep_by_summary=False, llm_pass=False)
# simple=39; summary_raw=79; norm=79.00;z_ref=(221.49,185.86); p70=253.00; llm_primary_pass conf=30, secs=[], google/gemma-3n-e4b preliminary rejects that, reason: llm_heavy_reject pass=False conf=30<58; secs=[]; why=The article discusses nuclear non-proliferation, a global issue, but does not focus on Ukraine or any of its specific concerns (Security & Civilian Impact, Health & Medical Services, Energy & Utilities, Water & Sanitation, Food & Markets). It's a general statement about international policy.; boosted=79; norm=79.00; z_ref=(221.49,185.86); p70=253.00
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165846
#
#       🆕 Fetched & cached: news.un.org/664160bf3d_2025-09-18.html
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165844
#
#       🆕 Fetched & cached: news.un.org/f058b2732f_2025-09-18.html
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=89, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 2, 'health': 1, 'energy': 0, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 10, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 10, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 89, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine records highest toll from cluster munitions for third year running, reason : crisis_hits=12 score=89
#
#   3. ✅ Light LLM main gate pass: Ukraine records highest toll from cluster munitions for third year running, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the humanitarian impact of cluster munitions in Ukraine, specifically mentioning casualties and tolls from these weapons. This directly aligns with the 'Security & Civilian Impact' section, detailing the harm inflicted on civilians and the conflict zone."}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine records highest toll from cluster munitions for third year running (keep=True, keep_by_summary=False, llm_pass=True)
# simple=89; summary_raw=189; norm=189.00;z_ref=(221.52,185.84); p70=253.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article focuses on casualties from cluster munitions in Ukraine, directly relating to civilian harm and the security situation. It also touches upon the health impacts of these munitions.'}
#   5. ✅ Heavy LLM final gate pass: Ukraine records highest toll from cluster munitions for third year running (keep=True, keep_by_summary=False, llm_pass=True)
# simple=89; summary_raw=189; norm=189.00;z_ref=(221.52,185.84); p70=253.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article focuses on casualties from cluster munitions in Ukraine, directly relating to civilian harm and the security situation. It also touches upon the health impacts of these munitions.'}
#     ✅ Cached: Ukraine records highest toll from cluster munitions for third year running | UN ... [news.un.org]
#   📦 Done: accepted=70, attempted=388, seen=389, target=70, cap=420)
# Building report for country: ukraine (max_items=50, per_section_cap=4)
# compose: found 50 rows for country: ukraine
# Coat of arms exists for title=ukraine
#
# compose: coat of arms ready at assets/coat_of_arms/ukraine.png
# [ROUTE] id=3170 -> section='Security & Civilian Impact' score=280 (cat_hits=4, txt_hits=6) (cap left: 3)
#         matches: civilian, school, child, brainwash, impact
# [ROUTE] id=1468 -> section='Security & Civilian Impact' score=280 (cat_hits=4, txt_hits=6) (cap left: 2)
#         matches: civilian, kill, dead, humanitar(y|ian), impact, brutal
# [ROUTE] id=3191 -> section='Security & Civilian Impact' score=240 (cat_hits=4, txt_hits=4) (cap left: 1)
#         matches: civilian, crisis, humanitar(y|ian), impact, underfund
# [ROUTE] id=2969 -> section='Security & Civilian Impact' score=220 (cat_hits=2, txt_hits=7) (cap left: 0)
#         matches: civilian, kill, dead, evacuat(e|ion), surviv(e|ors), impact
# [ROUTE] id=1766 -> section='Health & Medical Services' score=70 (cat_hits=0, txt_hits=7) (cap left: 3)
#         matches: elder, ill, pension
# [ROUTE] id=1767 -> section='Health & Medical Services' score=60 (cat_hits=2, txt_hits=2) (cap left: 2)
#         matches: injur(y|ed|ies), medical, ill
# [ROUTE] id=1855 -> section='Energy & Utilities' score=24 (cat_hits=1, txt_hits=2) (cap left: 3)
#         matches: energy, dam
# [ROUTE] id=3250 -> section='Health & Medical Services' score=40 (cat_hits=2, txt_hits=0) (cap left: 1)
#         matches: medical
# [ROUTE] id=1801 -> section='Health & Medical Services' score=10 (cat_hits=0, txt_hits=1) (cap left: 0)
#         matches: ill
# [ROUTE] id=1818 -> section='Food & Markets' score=8 (cat_hits=0, txt_hits=1) (cap left: 3)
#         matches: eat
# [ROUTE] id=3143 -> section='Food & Markets' score=32 (cat_hits=2, txt_hits=0) (cap left: 2)
#         matches: food, market
# [ROUTE] id=2751 -> section='Energy & Utilities' score=18 (cat_hits=1, txt_hits=1) (cap left: 2)
#         matches: energy, dam
# [ROUTE] id=3174 -> section='Energy & Utilities' score=24 (cat_hits=1, txt_hits=2) (cap left: 1)
#         matches: fuel, energy, oil
# [ROUTE] id=2554 -> section='Food & Markets' score=16 (cat_hits=0, txt_hits=2) (cap left: 1)
#         matches: eat
# [ROUTE] id=2968 -> section='Food & Markets' score=16 (cat_hits=1, txt_hits=0) (cap left: 0)
#         matches: eat
# [ROUTE] id=2 -> section='Energy & Utilities' score=18 (cat_hits=1, txt_hits=1) (cap left: 0)
#         matches: energy, dam
# Generating top summary body
#
# Generating Why Support
#
# Generating Conclusion
#
# Coat of arms exists for title=ukraine
#
# Coat of arms exists for title=ukraine
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 24
#      22 title = f"Humanitarian Situation Digest: {c.title()} — {format_us_date()}",
#      23 generate_docx_structured(sections, refs, "", f"data/reports/{base}.docx", country=c, report_title=title, section_order=report.get("section_order"))
# ---> 24 generate_pdf_structured(sections, refs, "", f"data/reports/{base}.pdf", country=c, report_title=title, section_order=report.get("section_order"))
#
# File ~/work/humanitarian_agent/src/report/docx_pdf.py:514, in generate_pdf_structured(sections, references_by_num, exec_overview, filename, country, report_title, section_order)
#     505 flow = []
#     506 #title_style = ParagraphStyle(name="TitleCenter", parent=styles["Title"], alignment=TA_CENTER)
#     507 #title_style.fontName = 'Arial'
#     508 #h1.fontName = 'Arial'
#    (...)    512 #flow.append(Paragraph(title, title_style))
#     513 #flow.append(Spacer(1, 12))
# --> 514 flow.append(header_with_coa_pdf(country, report_title, styles, total_width=LETTER[0]))
#     515 flow.append(Spacer(1, 0.2*inch))
#     517 # Executive Summary
#
# File ~/work/humanitarian_agent/src/report/docx_pdf.py:206, in header_with_coa_pdf(country, report_title, styles, img_size_in, gap_in, total_width)
#     203     img = Paragraph("⚠️ Coat of arms not available", styles["Normal"])
#     205 # Build the row: [img][gap][title]
# --> 206 title_para = Paragraph(report_title, styles["Title"])
#     207 data = [[img, Spacer(gap_in*inch, 0), title_para]]
#     209 if total_width:
#
# File /opt/conda/lib/python3.12/site-packages/reportlab/platypus/paragraph.py:1859, in Paragraph.__init__(self, text, style, bulletText, frags, caseSensitive, encoding)
#    1857 self.caseSensitive = caseSensitive
#    1858 self.encoding = encoding
# -> 1859 self._setup(text, style, bulletText or getattr(style,'bulletText',None), frags, cleanBlockQuotedText)
#
# File /opt/conda/lib/python3.12/site-packages/reportlab/platypus/paragraph.py:1877, in Paragraph._setup(self, text, style, bulletText, frags, cleaner)
#    1871 def _setup(self, text, style, bulletText, frags, cleaner):
#    1872
#    1873     #This used to be a global parser to save overhead.
#    1874     #In the interests of thread safety it is being instantiated per paragraph.
#    1875     #On the next release, we'll replace with a cElementTree parser
#    1876     if frags is None:
# -> 1877         text = cleaner(text)
#    1878         _parser = ParaParser()
#    1879         _parser.caseSensitive = self.caseSensitive
#
# File /opt/conda/lib/python3.12/site-packages/reportlab/platypus/paragraph.py:139, in cleanBlockQuotedText(text, joiner)
#     135 def cleanBlockQuotedText(text,joiner=' '):
#     136     """This is an internal utility which takes triple-
#     137     quoted text form within the document and returns
#     138     (hopefully) the paragraph the user intended originally."""
# --> 139     L=list(filter(truth,list(map(_lineClean, split(text, '\n')))))
#     140     return joiner.join(L)
#
# File /opt/conda/lib/python3.12/site-packages/reportlab/platypus/paragraph.py:96, in split(text, delim)
#      94 if isBytes(text): text = text.decode('utf8')
#      95 if delim is not None and isBytes(delim): delim = delim.decode('utf8')
# ---> 96 return [uword for uword in (_wsc_re_split(text) if delim is None and '\xa0' in text else text.split(delim))]
#
# AttributeError: 'tuple' object has no attribute 'split'
