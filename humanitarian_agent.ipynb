# %%
from src.db import init_db
from src.ingest.rss_loader import load_country
from src.report.compose import build_country_report
from src.validate.validators import validate_report
from src.report.compose import build_country_report
from src.report.docx_pdf import generate_docx_structured, generate_pdf_structured

init_db()

#for c in ["ukraine", "syria", "yemen"]:
for c in ["ukraine"]:
    load_country(c, max_items=30)
    report = build_country_report(c)
#    errors = validate_report(report)
#    print("Validation:", "PASS" if not errors else errors)
#    Optional: build an executive summary (or leave as empty string)
#    If you have llm_overview_plain already, plug it in; otherwise just pass "".
#    exec_overview = ""  # or llm_overview_plain(report.get("overview_texts", []))
    sections, refs, as_of = report["sections"], report["references_by_num"], report["as_of"]
#    If valid (or accept minor non-critical issues), render
    base = f"{c}_{as_of}"
    title = f"Humanitarian Situation Digest: {c.title()}"
    generate_docx_structured(sections, refs, "", f"data/reports/{base}.docx", country=c, report_title=title, section_order=report.get("section_order"))
    generate_pdf_structured(sections, refs, "", f"data/reports/{base}.pdf", country=c, report_title=title, section_order=report.get("section_order"))
# Out:
# /home/jovyan/work/humanitarian_agent/data/rss.sqlite3
#
# 🌍 Loading articles for: Ukraine (target accepts=30, max attempts=180)
#   🔗 Fetching feed: https://news.un.org/feed/subscribe/en/news/region/europe/feed/rss.xml
#   💾 Feed cache hit (fresh): news.un.org/023d4a80ab_2025-09-14.xml
#       ⚠️ Got 30 from feed: https://news.un.org/feed/subscribe/en/news/region/europe/feed/rss.xml
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165838
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/09/1165838 (news.un.org/2d0f48b28a_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-71, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 2, 'human_harm': 1, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 5, 'neg_exclude': 0, 'neg_frontline': 1}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': -15}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': -15, 'allow_bonus': 1}, 'boosted_score': -71, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165834
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/09/1165834 (news.un.org/579c1ccad9_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-26, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 2, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 6, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -120, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -120, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -26, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165820
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/09/1165820 (news.un.org/1504e45583_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-6, reason={'host': 'un.org', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 1, 'human_harm': 3, 'health': 0, 'energy': 1, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 5, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 60, 'health': 0, 'energy': 6, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 60, 'health': 0, 'energy': 6, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -100, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -6, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165803
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/09/1165803 (news.un.org/b019fe2a68_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=119, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 1, 'actors': 0, 'military': 2, 'human_harm': 3, 'health': 7, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 70, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 70, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 119, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine: Russian strike on village kills over 20, mostly pensioners, reason : crisis_hits=42 score=119
#
#   3. ✅ Light LLM main gate pass: Ukraine: Russian strike on village kills over 20, mostly pensioners, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the impact of a Russian airstrike on civilians in Ukraine, specifically mentioning elderly villagers and the broader civilian casualties. It discusses the humanitarian impact, including attacks on healthcare facilities and infrastructure, which aligns with the Security & Civilian Impact section.'}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine: Russian strike on village kills over 20, mostly pensioners (keep=True, keep_by_summary=True, llm_pass=True)
# simple=119; summary_raw=379; norm=379.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article details a Russian airstrike on a Ukrainian village, resulting in civilian casualties and damage to healthcare infrastructure. It directly addresses the harm to civilians and the healthcare system within Ukraine.'}
#   5. ✅ Heavy LLM final gate pass: Ukraine: Russian strike on village kills over 20, mostly pensioners (keep=True, keep_by_summary=True, llm_pass=True)
# simple=119; summary_raw=379; norm=379.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article details a Russian airstrike on a Ukrainian village, resulting in civilian casualties and damage to healthcare infrastructure. It directly addresses the harm to civilians and the healthcare system within Ukraine.'}
#     ✅ Cached: Ukraine: Russian strike on village kills over 20, mostly pensioners | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165793
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/09/1165793 (news.un.org/5bc3eb8094_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=61, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 61, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : UN provides urgent support after ‘massive’ Russian attack across Ukraine, reason : crisis_hits=31 score=61
#
#   3. ✅ Light LLM main gate pass: UN provides urgent support after ‘massive’ Russian attack across Ukraine, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the humanitarian impact of Russian attacks on Ukrainian civilians and infrastructure, specifically mentioning civilian casualties and damage to buildings. This directly aligns with the 'Security & Civilian Impact' section."}
#
#   4. ✅ Heavy LLM outer gate pass: UN provides urgent support after ‘massive’ Russian attack across Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=61; summary_raw=181; norm=181.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Aid'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Aid'], 'reason': 'The article directly addresses the impact of a Russian attack on Ukraine, including civilian casualties and damage to civilian infrastructure. It also mentions UN support, aligning with humanitarian aid.'}
#   5. ✅ Heavy LLM final gate pass: UN provides urgent support after ‘massive’ Russian attack across Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=61; summary_raw=181; norm=181.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Aid'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Aid'], 'reason': 'The article directly addresses the impact of a Russian attack on Ukraine, including civilian casualties and damage to civilian infrastructure. It also mentions UN support, aligning with humanitarian aid.'}
#     ✅ Cached: UN provides urgent support after ‘massive’ Russian attack across Ukraine | UN Ne... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/09/1165773
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/09/1165773 (news.un.org/de1511ef60_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=81, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 2, 'health': 3, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 40, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 81, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Finding strength amid sleepless nights: Ukraine’s hidden mental health toll, reason : crisis_hits=27 score=81
#
#   3. ✅ Light LLM main gate pass: Finding strength amid sleepless nights: Ukraine’s hidden mental health toll, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the mental health impact of the conflict in Ukraine on civilians, which falls under the 'Security & Civilian Impact' section. It discusses the toll on mental health, personal stories, and support efforts, aligning with the allowed section requirements."}
#
#   4. ✅ Heavy LLM outer gate pass: Finding strength amid sleepless nights: Ukraine’s hidden mental health toll (keep=True, keep_by_summary=False, llm_pass=True)
# simple=81; summary_raw=221; norm=221.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Health & Medical Services', 'Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Health & Medical Services', 'Security & Civilian Impact'], 'reason': "The article focuses on the mental health toll within Ukraine due to the ongoing conflict, directly impacting civilians and falling under 'Health & Medical Services' as well as 'Security & Civilian Impact'."}
#   5. ✅ Heavy LLM final gate pass: Finding strength amid sleepless nights: Ukraine’s hidden mental health toll (keep=True, keep_by_summary=False, llm_pass=True)
# simple=81; summary_raw=221; norm=221.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Health & Medical Services', 'Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Health & Medical Services', 'Security & Civilian Impact'], 'reason': "The article focuses on the mental health toll within Ukraine due to the ongoing conflict, directly impacting civilians and falling under 'Health & Medical Services' as well as 'Security & Civilian Impact'."}
#     ✅ Cached: Finding strength amid sleepless nights: Ukraine’s hidden mental health toll | UN... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165750
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165750 (news.un.org/84071901cf_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=35, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 1, 'human_harm': 2, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 40, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 40, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 35, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes, reason : crisis_hits=11 score=35
#
#   3. ✅ Light LLM main gate pass: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article primarily discusses the impact of Russian attacks on civilians in Ukraine, specifically mentioning casualties and damage to buildings. It focuses on the humanitarian consequences and the risk to diplomatic efforts for peace, aligning with the Security & Civilian Impact section.'}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes (keep=True, keep_by_summary=False, llm_pass=True)
# simple=35; summary_raw=115; norm=115.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on Russian strikes against civilians in Ukraine, the resulting casualties and damage, and the risk to diplomatic efforts for a lasting peace. This clearly falls under 'Security & Civilian Impact'."}
#   5. ✅ Heavy LLM final gate pass: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes (keep=True, keep_by_summary=False, llm_pass=True)
# simple=35; summary_raw=115; norm=115.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on Russian strikes against civilians in Ukraine, the resulting casualties and damage, and the risk to diplomatic efforts for a lasting peace. This clearly falls under 'Security & Civilian Impact'."}
#     ✅ Cached: Ukraine: ‘Diplomatic momentum’ at risk amid large-scale Russian strikes | UN New... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165733
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165733 (news.un.org/b8abf8f3ed_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=165, reason={'host': 'un.org', 'counts': {'core': 4, 'cities': 2, 'actors': 0, 'military': 0, 'human_harm': 5, 'health': 2, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 2, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 60, 'cities': 20, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 24, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 60, 'cities': 20, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 24, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 165, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv, reason : crisis_hits=28 score=165
#
#   3. ✅ Light LLM main gate pass: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the humanitarian impact of Russia's attacks on Ukrainian civilians, specifically mentioning a toddler killed and dozens injured. It discusses the violation of international humanitarian law and calls for an immediate ceasefire, all directly related to the civilian impact in Ukraine."}
#
#   4. ✅ Heavy LLM outer gate pass: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv (keep=True, keep_by_summary=True, llm_pass=True)
# simple=165; summary_raw=365; norm=365.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly addresses civilian casualties and the impact of attacks on Kyiv, falling under 'Security & Civilian Impact'. It also touches upon the humanitarian crisis and the impact on children's well-being, relating to 'Health & Medical Services'."}
#   5. ✅ Heavy LLM final gate pass: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv (keep=True, keep_by_summary=True, llm_pass=True)
# simple=165; summary_raw=365; norm=365.00;z_ref=(219.50,168.44); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly addresses civilian casualties and the impact of attacks on Kyiv, falling under 'Security & Civilian Impact'. It also touches upon the humanitarian crisis and the impact on children's well-being, relating to 'Health & Medical Services'."}
#     ✅ Cached: Ukraine: Toddler among four children killed in Russia’s attacks on Kyiv | UN New... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165685
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165685 (news.un.org/7a5b327794_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-9, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -9, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165671
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165671 (news.un.org/0a4e981507_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=111, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 1, 'actors': 0, 'military': 0, 'human_harm': 4, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 111, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope, reason : crisis_hits=13 score=111
#
#   3. ✅ Light LLM main gate pass: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on Ukrainian aid workers and the humanitarian crisis in Ukraine, specifically mentioning displacement, evacuation efforts, and the impact on civilians. It does not contain elements related to Ukraine's security, health services, energy, water, or food markets, nor does it discuss neighboring countries or unrelated topics."}
#
#   4. ✅ Heavy LLM outer gate pass: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope (keep=True, keep_by_summary=True, llm_pass=True)
# simple=111; summary_raw=271; norm=271.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Aid'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Aid'], 'reason': 'The article focuses on the impact of the conflict on Ukrainian civilians, specifically highlighting the work of a humanitarian aid worker in the context of displacement due to the conflict. It directly addresses the security situation and civilian impact within Ukraine.'}
#   5. ✅ Heavy LLM final gate pass: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope (keep=True, keep_by_summary=True, llm_pass=True)
# simple=111; summary_raw=271; norm=271.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Aid'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Aid'], 'reason': 'The article focuses on the impact of the conflict on Ukrainian civilians, specifically highlighting the work of a humanitarian aid worker in the context of displacement due to the conflict. It directly addresses the security situation and civilian impact within Ukraine.'}
#     ✅ Cached: First Person: On Ukraine’s frontlines, humanitarians risk all to bring hope | UN... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165668
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165668 (news.un.org/417bbbc0f5_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=117, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 2, 'actors': 0, 'military': 2, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 20, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 20, 'actors': 0, 'military': 8, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 117, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’, reason : crisis_hits=14 score=117
#
#   3. ✅ Light LLM main gate pass: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the humanitarian impact of Russian drone strikes on Ukrainian civilians, specifically mentioning deaths and casualties among children. It discusses the UN's call for peace and the ongoing conflict, directly addressing the harm done to civilians in Ukraine."}
#
#   4. ✅ Heavy LLM outer gate pass: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’ (keep=True, keep_by_summary=False, llm_pass=True)
# simple=117; summary_raw=237; norm=237.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article directly discusses civilian casualties from Russian drone strikes in Ukraine, explicitly mentioning deaths and the impact on children. It also references the role of UNICEF, indicating a concern for civilian well-being.'}
#   5. ✅ Heavy LLM final gate pass: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehensive and sustainable peace’ (keep=True, keep_by_summary=False, llm_pass=True)
# simple=117; summary_raw=237; norm=237.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': 'The article directly discusses civilian casualties from Russian drone strikes in Ukraine, explicitly mentioning deaths and the impact on children. It also references the role of UNICEF, indicating a concern for civilian well-being.'}
#     ✅ Cached: More young lives lost in Ukraine, as UN chief repeats call for a ‘just, comprehe... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165660
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165660 (news.un.org/c0fc9291ec_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-9, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -9, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165558
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165558 (news.un.org/214fb08c36_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=177, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 4, 'human_harm': 6, 'health': 3, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 16, 'human_harm': 120, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 16, 'human_harm': 120, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 177, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : UN official decries deadly Ukraine strikes, urges return to diplomacy, reason : crisis_hits=40 score=177
#
#   3. ✅ Light LLM main gate pass: UN official decries deadly Ukraine strikes, urges return to diplomacy, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the humanitarian impact of strikes in Ukraine, specifically mentioning civilian casualties, damaged infrastructure affecting schools and hospitals, and calls for a return to diplomacy. This directly aligns with the 'Security & Civilian Impact' section."}
#
#   4. ✅ Heavy LLM outer gate pass: UN official decries deadly Ukraine strikes, urges return to diplomacy (keep=True, keep_by_summary=True, llm_pass=True)
# simple=177; summary_raw=417; norm=417.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Impact'], 'reason': 'The article focuses on civilian casualties and humanitarian conditions in Ukraine due to Russian strikes, directly aligning with the allowed sections of Security & Civilian Impact and Humanitarian Impact. It details damage to civilian infrastructure like schools and hospitals, confirming its relevance.'}
#   5. ✅ Heavy LLM final gate pass: UN official decries deadly Ukraine strikes, urges return to diplomacy (keep=True, keep_by_summary=True, llm_pass=True)
# simple=177; summary_raw=417; norm=417.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Impact'], 'reason': 'The article focuses on civilian casualties and humanitarian conditions in Ukraine due to Russian strikes, directly aligning with the allowed sections of Security & Civilian Impact and Humanitarian Impact. It details damage to civilian infrastructure like schools and hospitals, confirming its relevance.'}
#     ✅ Cached: UN official decries deadly Ukraine strikes, urges return to diplomacy | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/08/1165555
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/08/1165555 (news.un.org/cf6275d7e5_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=81, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 3, 'health': 1, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 60, 'health': 10, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 81, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : LIVE: UN Security Council meets on crisis in Ukraine, reason : crisis_hits=8 score=81
#
#   3. ✅ Light LLM main gate pass: LIVE: UN Security Council meets on crisis in Ukraine, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article focuses on the UN Security Council meeting regarding the crisis in Ukraine, detailing the situation and expected briefing. It directly addresses harm to civilians, health impacts, and economic consequences, aligning with the Security & Civilian Impact section.'}
#
#   4. ✅ Heavy LLM outer gate pass: LIVE: UN Security Council meets on crisis in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=81; summary_raw=221; norm=221.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article explicitly discusses a crisis in Ukraine involving attacks resulting in casualties, which falls under the scope of 'Security & Civilian Impact'."}
#   5. ✅ Heavy LLM final gate pass: LIVE: UN Security Council meets on crisis in Ukraine (keep=True, keep_by_summary=False, llm_pass=True)
# simple=81; summary_raw=221; norm=221.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article explicitly discusses a crisis in Ukraine involving attacks resulting in casualties, which falls under the scope of 'Security & Civilian Impact'."}
#     ✅ Cached: LIVE: UN Security Council meets on crisis in Ukraine | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165540
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/07/1165540 (news.un.org/eb17c15465_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=122, reason={'host': 'un.org', 'counts': {'core': 3, 'cities': 1, 'actors': 0, 'military': 1, 'human_harm': 4, 'health': 3, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 1, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 4, 'human_harm': 80, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 4, 'human_harm': 80, 'health': 30, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 122, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Russian attack on Ukrainian capital kills at least 11 civilians, reason : crisis_hits=28 score=122
#
#   3. ✅ Light LLM main gate pass: Russian attack on Ukrainian capital kills at least 11 civilians, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 100, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on a specific event (Russian attack on Ukrainian capital) resulting in civilian casualties and damage, directly aligning with the 'Security & Civilian Impact' section. It does not discuss Ukraine's economy, health services, energy, water, or neighboring countries."}
#
#   4. ✅ Heavy LLM outer gate pass: Russian attack on Ukrainian capital kills at least 11 civilians (keep=True, keep_by_summary=True, llm_pass=True)
# simple=122; summary_raw=282; norm=282.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly reports on civilian casualties and damage caused by a Russian attack on the capital of Ukraine, clearly falling under 'Security & Civilian Impact' and 'Health & Medical Services' due to the injuries reported."}
#   5. ✅ Heavy LLM final gate pass: Russian attack on Ukrainian capital kills at least 11 civilians (keep=True, keep_by_summary=True, llm_pass=True)
# simple=122; summary_raw=282; norm=282.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly reports on civilian casualties and damage caused by a Russian attack on the capital of Ukraine, clearly falling under 'Security & Civilian Impact' and 'Health & Medical Services' due to the injuries reported."}
#     ✅ Cached: Russian attack on Ukrainian capital kills at least 11 civilians | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165539
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/07/1165539 (news.un.org/5b0e1b3d4c_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-71, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 1, 'city_geo': 0, 'neg_geo_only': 4, 'neg_exclude': 1, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -80, 'neg_exclude': -30, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 8, 'city_geo': 0, 'neg_geo_only': -80, 'neg_exclude': -30, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -71, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165520
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/07/1165520 (news.un.org/6f9b8b0358_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=156, reason={'host': 'un.org', 'counts': {'core': 3, 'cities': 1, 'actors': 0, 'military': 0, 'human_harm': 5, 'health': 2, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 45, 'cities': 10, 'actors': 0, 'military': 0, 'human_harm': 100, 'health': 20, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 156, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Russian attack on Ukrainian prison kills 16: UN rights monitors, reason : crisis_hits=37 score=156
#
#   3. ✅ Light LLM main gate pass: Russian attack on Ukrainian prison kills 16: UN rights monitors, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 100, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on a specific attack in Ukraine, its casualties, and the violation of international law, directly aligning with the 'Security & Civilian Impact' section. It does not discuss health, energy, water, food markets, or neighboring countries."}
#
#   4. ✅ Heavy LLM outer gate pass: Russian attack on Ukrainian prison kills 16: UN rights monitors (keep=True, keep_by_summary=True, llm_pass=True)
# simple=156; summary_raw=356; norm=356.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article details a Russian attack on a Ukrainian prison, resulting in civilian casualties and damage to a hospital. This directly relates to Security & Civilian Impact.'}
#   5. ✅ Heavy LLM final gate pass: Russian attack on Ukrainian prison kills 16: UN rights monitors (keep=True, keep_by_summary=True, llm_pass=True)
# simple=156; summary_raw=356; norm=356.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': 'The article details a Russian attack on a Ukrainian prison, resulting in civilian casualties and damage to a hospital. This directly relates to Security & Civilian Impact.'}
#     ✅ Cached: Russian attack on Ukrainian prison kills 16: UN rights monitors | UN News... [news.un.org]
#         Got article https://news.un.org/feed/view/en/story/2025/07/1165499
#
#       💾 Cache hit (today): https://news.un.org/feed/view/en/story/2025/07/1165499 (news.un.org/8d53bc63d6_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=91, reason={'host': 'un.org', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 4, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 80, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 91, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall, reason : crisis_hits=21 score=91
#
#   3. ✅ Light LLM main gate pass: UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 100, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the escalating human toll and humanitarian needs in Ukraine due to Russian aerial attacks, directly addressing civilian impact and the broader security situation. It does not mention Ukraine's economy, health services, energy, water, or neighboring countries, aligning with the allowed section and criteria."}
#
#   4. ✅ Heavy LLM outer gate pass: UN warns of escalating human toll in Ukraine amid relentless aerial attacks, mounting aid shortfall (keep=True, keep_by_summary=False, llm_pass=True)
# simple=91; summary_raw=251; norm=251.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Humanitarian Needs'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Humanitarian Needs'], 'reason': 'The article focuses on the escalating human toll and damage to civilian infrastructure in Ukraine due to Russian aerial attacks, highlighting humanitarian needs and aid shortfalls. It directly addresses the impact on civilians and civilian infrastructure within Ukraine.'}
# ...
#
#         Got article https://www.bbc.com/news/videos/c6205ezp6nlo?at_medium=RSS&at_campaign=rss
#
#       💾 Cache hit (today): https://www.bbc.com/news/videos/c6205ezp6nlo?at_medium=RSS&at_campaign=rss (www.bbc.com/547d7e230e_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-44, reason={'host': 'bbc.com', 'counts': {'core': 1, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 3, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -60, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -44, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://www.bbc.com/news/videos/cwyn3gnnvv3o?at_medium=RSS&at_campaign=rss
#
#       💾 Cache hit (today): https://www.bbc.com/news/videos/cwyn3gnnvv3o?at_medium=RSS&at_campaign=rss (www.bbc.com/1ee9757a35_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=92, reason={'host': 'bbc.com', 'counts': {'core': 1, 'cities': 1, 'actors': 0, 'military': 2, 'human_harm': 2, 'health': 0, 'energy': 1, 'water': 0, 'food': 0, 'city_geo': 1, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 15, 'cities': 10, 'actors': 0, 'military': 8, 'human_harm': 40, 'health': 0, 'energy': 6, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 15, 'cities': 10, 'actors': 0, 'military': 8, 'human_harm': 40, 'health': 0, 'energy': 6, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': 0, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 92, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Inside Kyiv government building hit by missile strike, reason : crisis_hits=12 score=92
#
#   3. ✅ Light LLM main gate pass: Inside Kyiv government building hit by missile strike, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on a missile strike against Ukraine's government building in Kyiv, detailing the damage and casualties. This directly relates to the security and civilian impact of the conflict in Ukraine."}
#
#   4. ✅ Heavy LLM outer gate pass: Inside Kyiv government building hit by missile strike (keep=True, keep_by_summary=False, llm_pass=True)
# simple=92; summary_raw=172; norm=172.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article directly discusses a missile strike on a government building in Kyiv, Ukraine, causing damage. This falls under 'Security & Civilian Impact' as it involves damage to infrastructure and a civilian government building due to conflict."}
#   5. ✅ Heavy LLM final gate pass: Inside Kyiv government building hit by missile strike (keep=True, keep_by_summary=False, llm_pass=True)
# simple=92; summary_raw=172; norm=172.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article directly discusses a missile strike on a government building in Kyiv, Ukraine, causing damage. This falls under 'Security & Civilian Impact' as it involves damage to infrastructure and a civilian government building due to conflict."}
#     ✅ Cached: Inside Kyiv government building hit by missile strike... [www.bbc.com]
#         Got article https://www.bbc.com/news/articles/cr4e435x4kqo?at_medium=RSS&at_campaign=rss
#
#       💾 Cache hit (today): https://www.bbc.com/news/articles/cr4e435x4kqo?at_medium=RSS&at_campaign=rss (www.bbc.com/dbbd1dfa2d_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-24, reason={'host': 'bbc.com', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 1}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': -15}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': -15, 'allow_bonus': 1}, 'boosted_score': -24, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://www.bbc.com/sport/football/articles/c80glg2jep1o?at_medium=RSS&at_campaign=rss
#
#       💾 Cache hit (today): https://www.bbc.com/sport/football/articles/c80glg2jep1o?at_medium=RSS&at_campaign=rss (www.bbc.com/39f0db7f80_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=139, reason={'host': 'bbc.com', 'counts': {'core': 2, 'cities': 1, 'actors': 0, 'military': 1, 'human_harm': 5, 'health': 1, 'energy': 2, 'water': 0, 'food': 0, 'city_geo': 1, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 4, 'human_harm': 100, 'health': 10, 'energy': 12, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 4, 'human_harm': 100, 'health': 10, 'energy': 12, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 139, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Sudakov's apartment damaged in Russia attack, reason : crisis_hits=22 score=139
#
#   3. ✅ Light LLM main gate pass: Sudakov's apartment damaged in Russia attack, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 100, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the damage to Georgiy Sudakov's apartment in Kyiv, Ukraine, caused by a Russian drone attack. It details the impact on Sudakov and his family, mentioning casualties and damage to civilian property, directly aligning with the 'Security & Civilian Impact' section."}
#
#   4. ✅ Heavy LLM outer gate pass: Sudakov's apartment damaged in Russia attack (keep=True, keep_by_summary=True, llm_pass=True)
# simple=139; summary_raw=359; norm=359.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly describes damage to a civilian's home in Kyiv due to a Russian drone attack, resulting in casualties. This clearly falls under Security & Civilian Impact and Health & Medical Services (due to injuries)."}
#   5. ✅ Heavy LLM final gate pass: Sudakov's apartment damaged in Russia attack (keep=True, keep_by_summary=True, llm_pass=True)
# simple=139; summary_raw=359; norm=359.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact', 'Health & Medical Services'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact', 'Health & Medical Services'], 'reason': "The article directly describes damage to a civilian's home in Kyiv due to a Russian drone attack, resulting in casualties. This clearly falls under Security & Civilian Impact and Health & Medical Services (due to injuries)."}
#     ✅ Cached: Georgiy Sudakov: Ukraine midfielder says Kyiv apartment severely damaged in Russ... [www.bbc.com]
#         Got article https://www.bbc.com/news/articles/cvg0e54z7x8o?at_medium=RSS&at_campaign=rss
#
#       💾 Cache hit (today): https://www.bbc.com/news/articles/cvg0e54z7x8o?at_medium=RSS&at_campaign=rss (www.bbc.com/77ab601ddd_2025-09-14.html)
#   1. ❌ Pre-LLM outer gate reject (low score) : keep=False, score=-9, reason={'host': 'bbc.com', 'counts': {'core': 2, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': 2, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 0, 'neg_geo_only': -40, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': -9, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#         Got article https://www.bbc.com/news/videos/cy04lx67e1eo?at_medium=RSS&at_campaign=rss
#
#       💾 Cache hit (today): https://www.bbc.com/news/videos/cy04lx67e1eo?at_medium=RSS&at_campaign=rss (www.bbc.com/3740fd4950_2025-09-14.html)
#   1. ✅ Pre-LLM outer gate pass (good score) : keep=True, score=69, reason={'host': 'bbc.com', 'counts': {'core': 2, 'cities': 1, 'actors': 0, 'military': 4, 'human_harm': 1, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 1, 'neg_geo_only': 1, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_before_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 16, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0}, 'contrib_after_boost': {'core': 30, 'cities': 10, 'actors': 0, 'military': 16, 'human_harm': 20, 'health': 0, 'energy': 0, 'water': 0, 'food': 0, 'city_geo': 12, 'neg_geo_only': -20, 'neg_exclude': 0, 'neg_frontline': 0, 'allow_bonus': 1}, 'boosted_score': 69, 'threshold': 30, 'allowlisted': True, 'cat_hits_by_bag': {'core': 0, 'cities': 0, 'actors': 0, 'military': 0, 'human_harm': 0, 'health': 0, 'energy': 0, 'water': 0, 'food': 0}, 'core_cat_hit': False, 'method': 'summary_score'}
#
#   2. ✅ Pre-LLM inner gate keyword + crisis-signal check pass : Watch: BBC at the scene of Ukrainian government building strike, reason : crisis_hits=6 score=69
#
#   3. ✅ Light LLM main gate pass: Watch: BBC at the scene of Ukrainian government building strike, liquid/lfm2-1.2b approves that, reason : {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article focuses on the impact of military actions (missile and drone strikes) on civilians in Ukraine, specifically mentioning casualties and damage to government buildings. This directly aligns with the 'Security & Civilian Impact' section."}
#
#   4. ✅ Heavy LLM outer gate pass: Watch: BBC at the scene of Ukrainian government building strike (keep=True, keep_by_summary=False, llm_pass=True)
# simple=69; summary_raw=109; norm=109.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b preliminary approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article directly reports on damage to a government building and residential buildings in Kyiv due to Russian missile and drone strikes, resulting in casualties. This clearly falls under 'Security & Civilian Impact'."}
#   5. ✅ Heavy LLM final gate pass: Watch: BBC at the scene of Ukrainian government building strike (keep=True, keep_by_summary=False, llm_pass=True)
# simple=69; summary_raw=109; norm=109.00;z_ref=(219.07,168.01); p70=267.00; llm_primary_pass conf=95, secs=['Security & Civilian Impact'], google/gemma-3n-e4b finally approves that, reason: {'pass': True, 'confidence': 95, 'sections': ['Security & Civilian Impact'], 'reason': "The article directly reports on damage to a government building and residential buildings in Kyiv due to Russian missile and drone strikes, resulting in casualties. This clearly falls under 'Security & Civilian Impact'."}
#     ✅ Cached: Watch: BBC at the scene of Ukrainian government building strike... [www.bbc.com]
#   📦 Done: accepted=30, attempted=62, seen=62, target=30, cap=180)
# Building report for country: ukraine (max_items=15, per_section_cap=4)
# compose: found 15 rows for country: ukraine
# [ROUTE] id=2969 -> section='Security & Civilian Impact' score=220 (cat_hits=2, txt_hits=7) (cap left: 3)
#         matches: civilian, kill, dead, evacuat(e|ion), surviv(e|ors), impact
# [ROUTE] id=2980 -> section='Security & Civilian Impact' score=180 (cat_hits=2, txt_hits=5) (cap left: 2)
#         matches: civilian, emergency, shelling, hit, impact, violat(e|ion)
# [ROUTE] id=2751 -> section='Security & Civilian Impact' score=160 (cat_hits=2, txt_hits=4) (cap left: 1)
#         matches: civilian, dead, emergency, impact, violat(e|ion)
# [ROUTE] id=2968 -> section='Security & Civilian Impact' score=140 (cat_hits=2, txt_hits=3) (cap left: 0)
#         matches: civilian, kill, dead, impact
# [ROUTE] id=2966 -> section='Energy & Utilities' score=24 (cat_hits=1, txt_hits=2) (cap left: 3)
#         matches: energy, oil
# [ROUTE] id=2554 -> section='Health & Medical Services' score=70 (cat_hits=2, txt_hits=3) (cap left: 3)
#         matches: injur(y|ed|ies), medical, recover
# [ROUTE] id=2967 -> section='Health & Medical Services' score=50 (cat_hits=2, txt_hits=1) (cap left: 2)
#         matches: medical, ill
# [ROUTE] id=2555 -> section='Health & Medical Services' score=100 (cat_hits=2, txt_hits=6) (cap left: 1)
#         matches: wound, injur(y|ed|ies), medical, ill, recover
# [ROUTE] id=2978 -> section='Energy & Utilities' score=24 (cat_hits=1, txt_hits=2) (cap left: 2)
#         matches: energy, oil
# [ROUTE] id=3044 -> section='Health & Medical Services' score=60 (cat_hits=2, txt_hits=2) (cap left: 0)
#         matches: wound, medical
# [ROUTE] id=2608 -> section='Energy & Utilities' score=12 (cat_hits=1, txt_hits=0) (cap left: 1)
#         matches: energy
# [ROUTE] id=3051 -> section='Energy & Utilities' score=18 (cat_hits=1, txt_hits=1) (cap left: 0)
#         matches: energy, oil
